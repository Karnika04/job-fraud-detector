# %% [markdown]
# # EMSCAD EDA
#
# Exploratory data analysis notebook for the Employment Scam Aegean Dataset (EMSCAD).

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

raw_path = "../data/raw_dataset.csv"
df = pd.read_csv(raw_path)
df.head()
